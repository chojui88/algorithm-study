# %%
a = int(input('your a?'))
b = int(input('your second?'))

print("{0} + {1} = {2}".format(a,b,a+b))
# Out:
# 1 + 2 = 3

# %%
print(9//-2)
# Out:
# -5

# %%
print(-9%2)
# Out:
# 1

# %%
birth=int(input())
year = birth//10000
month = birth//100 % 100
day = birth%100

print(year,month,day)
# Out:
# 1999 23 23

# %%
celsius = int(input())
fahrengeit = (9/5)*celsius + 32
print(celsius,"도는 화씨",fahrengeit,"도 입니다.")
# Out:
# 24 도는 화씨 75.2 도 입니다.

# %%
a = int(input('첫번째 수'))
b = int(input('두 번째 수'))

print('a = ',a,":",bin(a))

print(a&b,bin(a&b))
print(~a, bin(~a)) # ~이건 뒤집는다는 ㄴ뜻
# Out:
# a =  1 : 0b1
# 0 0b0
# -2 -0b10

# %%
a = int(input())
b = int(input())

print('a = {0}, b =  {1}'.format(a,b))
print(a,":",bin(a))

# %% [markdown]
# a = a ^ b
# a 는 2, b는 3일때
# a는 10, b는 11이다.
# a = 01
#
# b = a^b = 10 (2)
# a = a^b = 11 (3)
#
#
# 어떤 값에 0을 ^ 하면 자기 자신이 된다

# %%
year = int(input())
print(year%4==0 and year%100 !=0 or year%400 == 0)
# Out:
# True

# %%
a = int(input('첫 번째 숫자:'))
b = int(input('두 번째 숫자:'))
print('-' * 15)
print(f"{a} + {b} = {a+b}")
print("{0} - {1} = {2}".format(a,b,a-b))
print("%d * %d = %d" %(a,b,a*b))
# Out:
# ---------------
# 10 + 3 = 13
# 10 - 3 = 7
# 10 * 3 = 30

# %% [markdown]
# [에러]
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 5
#       3 print('-' * 15)
#       4 print(f"{a} + {b} = {a+b}")
# ----> 5 print({1}," - ",{2}," = ",{3}.format(a,b,a-b))
#       6 print("%d * %d = %d" %(a,b,a*b))
#
# AttributeError: 'set' object has no attribute 'format'
#
# [문제]
# .format을 쓸때, 변수도 문자열로 감싸야 함
# 그리고 콤마로 구분하지 않고, 출력문 자체를 감싸기
# 그리고 인덱스는 0부터 시작하기
#
# [해결]
# print("{0} - {1}".format(a,a-b))

# %%
money = int(input('교환할 돈을 입력하시오:'))
m_50000 = money // 50000
money%= 50000

m_10000 = money // 10000
money %= 10000
print(money% , end = ",")
