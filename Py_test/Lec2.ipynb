# %%
print("The is %f"%3.8)
print('%d 학년이다'%1)
print('|%30s|' % 'Artifical')
print('|%-30s|' % 'Artificial')
print('|%-10.5f|' %3.14)
print('|%10.5f|' %3.14)
# Out:
# The is 3.800000
# 1 학년이다
# |                     Artifical|
# |Artificial                    |
# |3.14000   |
# |   3.14000|

# %%
"""Life is short"""
# Out:
# 'Life is short'

# %%
str6 = 'Deperment of {}'
print(str6.format('AI'))
# Out:
# Deperment of AI

# %%
str6 = 'Dapartment of {} {}'
print(str6.format('Com','Eng'))
# Out:
# Dapartment of Com Eng

# %%
str7 = 'Deparment of {:&<20}'
print(str7.format('Engeen'))
# Out:
# Deparment of Engeen&&&&&&&&&&&&&&

# %%
apple = int(input('사과의 개수:'))
banana = int(input('바나나의 개수:'))


print('사과 {}개의 총합:{}원, 바나나 {}개의 총합:{}원'.format(apple,apple*2000,banana,banana*1500))
# Out:
# 사과 1개의 총합:2000원, 바나나 2개의 총합:3000원
