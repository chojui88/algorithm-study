# %%
import time

#버블 정렬!
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j
        if arr[j] > 


return arr
# Out:
#   Cell In[1], line 7
#     for j
#          ^
# SyntaxError: invalid syntax

# %%
#sort 함수 배열로 정렬

def do_sort(arr): 
    arr.sort()
    return arr

def measure_time(func,arr) #시간 측정, 뒤집힌 배열
    start_time = time.time()
    result = func(arr)
    end_time = time.time()
    return end_time - start_time, result

arr = list(range(10000))

bubble_time, bubble_result = measure_time(bubble_sort, arr)
measure_time(do_sort,arr)
