# %%
def solution(numbers):
    #정수 배열에서, 다른 인덱스 2개의 수를뽑아
    arr = []
    for i in range(length(numbers)):
        for j in range (i,length(numbers)):
            #만약 arr에 없으면 여기에 담고 
            arr.append(numbers[i]+numbers[j])

            #있으면 그냥 패스

    #배열에 오름차순으로 담아
    arr.sort()

    return arr

# %%
def solution(numbers):
    #정수 배열에서, 다른 인덱스 2개의 수를뽑아
    arr = []
    for i in range(len(numbers)):
        for j in range (i+1,len(numbers)):
            #만약 arr에 없으면 여기에 담고 
            if numbers[i] + numbers[j] not in arr:
                arr.append(numbers[i]+numbers[j])

            #있으면 그냥 패스

    #ret = sorted(set(ret))
    #배열에 오름차순으로 담아
    arr.sort()

    return arr
