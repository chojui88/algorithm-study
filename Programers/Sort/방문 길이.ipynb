# %%
def solution(dirs):
    graph = (0,0,0),
    
    for i in dirs:
        if 'U' == (0,+1)
        elif 'D' == (0,-1)
        elif 'R' == (+1,0)
        elif 'R' == (-1,0)

    #그래프를 한번 거쳐서
    if graph의 마지막 값이 0이라면
        graph.append(1)
        #1이라고 깃발을 꽃고
        count+=1 
        그 길이를 센다.


    

    #제한 범위
    answer = 0
    return answer
