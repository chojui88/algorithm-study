# %%
def solution(s):

    before = ''
    stack = []
    for i in range(len(s)):
        stack.append(s[i])
        
        if s[i] == ')' and before == '(':
            stack.pop()
            stack.pop()
            before = s[i-2] if i >=2 else ''
        else:
            before = s[i]

    return not stack

# %%
def solution(s):
    stack = []
    for c in s:
        if c == "(":
            stack.append(c)
        elif c == ")":
            if not stack:
                return False
            else: 
                stack.pop()
    if stack:
        return False
    else:
        return True
