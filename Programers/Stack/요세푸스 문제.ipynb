# %%
def solution(n, k):
    queue = []
    for i in range(1,n+1):
        queue.append(i)

    while : queue
        for i in range(k-1):
            a = queue.pop(0)
            queue.rearpush(a)
        queue.pop(0)
    # 원형 덱으로 변형해서, 계쏙 k값을 뺴고 빼고 해서 최종남은 값의 수

    return

# %%
from collections import deque

def solution(n,k):
    queue = deque(range(1,n+1))

    while len(queue) >1 :
        for _ in range(k-1):
            queue.append(queue.popleft())

        queue.popleft()
    return queue[0]
